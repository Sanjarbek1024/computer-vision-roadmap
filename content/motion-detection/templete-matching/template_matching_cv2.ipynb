# %%
import cv2

# %%
cv2.__version__
# Out:
# '5.0.0'

# %%
import numpy as np

# %%
from pathlib import Path

VIDEO_PATH = Path('assets/cup.mp4')
VIDEO_PATH
# Out:
# WindowsPath('assets/cup.mp4')

# %% [markdown]
# #### **Opening the video**

# %%
capture = cv2.VideoCapture(str(VIDEO_PATH))

# %%
capture = cv2.VideoCapture('assets/cup.mp4')

# %%
type(capture)
# Out:
# cv2.VideoCapture

# %%
capture.isOpened()
# Out:
# True

# %%
ret, frame = capture.read()

# %%
ret
# Out:
# True

# %%
type(frame)
# Out:
# numpy.ndarray

# %%
frame.shape
# Out:
# (1920, 1080, 3)

# %%
from PIL import Image

# %%
img = Image.fromarray(frame)

# %%
img.show()

# %%
cv2.imshow("First Frame", frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
fps = capture.get(cv2.CAP_PROP_FPS)

# %%
fps
# Out:
# 29.27541614807962

# %%
width = capture.get(cv2.CAP_PROP_FRAME_WIDTH)
width
# Out:
# 1080.0

# %%
height = capture.get(cv2.CAP_PROP_FRAME_HEIGHT)
height
# Out:
# 1920.0

# %%
width = int(width)
height = int(height)

# %%
capture.set(cv2.CAP_PROP_POS_FRAMES, 0)
# Out:
# True

# %%
ret, first_frame = capture.read()

# %%
first_frame.shape

# %%
x, y, w, h = cv2.selectROI(
    "Select Template",
    first_frame,
    fromCenter=False,
    showCrosshair=True
)
